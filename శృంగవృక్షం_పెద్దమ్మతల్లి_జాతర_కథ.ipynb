# %%
# !unzip "Noto_Serif_Telugu.zip" -d font
# Out:
# Archive:  Noto_Serif_Telugu.zip
#  extracting: font/OFL.txt
#  extracting: font/README.txt
#  extracting: font/static/NotoSerifTelugu-SemiBold.ttf
#  extracting: font/static/NotoSerifTelugu-Light.ttf
#  extracting: font/static/NotoSerifTelugu-ExtraBold.ttf
#  extracting: font/static/NotoSerifTelugu-Medium.ttf
#  extracting: font/static/NotoSerifTelugu-Thin.ttf
#  extracting: font/static/NotoSerifTelugu-ExtraLight.ttf
#  extracting: font/static/NotoSerifTelugu-Black.ttf
#  extracting: font/static/NotoSerifTelugu-Regular.ttf
#  extracting: font/static/NotoSerifTelugu-Bold.ttf
#  extracting: font/NotoSerifTelugu-VariableFont_wght.ttf

# %%
# !pip install gtts

# %%
pip install moviepy opencv-python Pillow numpy

# %%
# !pip install moviepy

# %%
import cv2
import numpy as np
import os
from gtts import gTTS
from PIL import Image, ImageFont, ImageDraw
from moviepy.editor import VideoFileClip, AudioFileClip, concatenate_videoclips
import textwrap # Import the textwrap module
# --- Configuration ---
OUTPUT_FOLDER = "stotra_video_output"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
TEMP_FOLDER = os.path.join(OUTPUT_FOLDER, "temp")
os.makedirs(TEMP_FOLDER, exist_ok=True)
# Define media paths
telugu_font_path = "font/static/NotoSerifTelugu-Regular.ttf"
image_d1 = "viva.png"
image_d2 = "title.jpg"
image_d3 = "pedhama.png"
image_d4 = "pedama.png"
image_d5 = "peba.png"
image_d6 = "peba2.png"
image_d7 = "nog.png"
image_d8 = "bakthu.png"
image_d9 = "bakthu1.png"
image_d10 = "gram.png"
image_d11 = "viel.png"
#image_d12 = "gram2.png"

# --- Story Content (Telugu Script) ---

    #1
story_parts = [
    {
        "title": "The Vedansh Devotional channel",
        "text": [
            "Welcome to My channel viewers ",

        ],
        "image": image_d2
    },

    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [
            "ప్రదేశ పరిచయం",#1
            "Srungavruksham Peddamathalli Temple ఈ ఆలయం తూర్పు గోదావరి ప్రాంతంలో ఎంతో",
            "పవిత్రమైన గ్రామదేవత స్థలం. పెద్దమ్మతల్లి జాతర ఎంతో వైభవంగా జరుగుతుంది."

        ],
        "image": image_d3
    },

    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#2
            "నారేటర్:పూర్వం… శృంగవృక్షం గ్రామం చిన్నదైనా, భక్తి చాలా గొప్పది.",
            "కానీ ఒకసారి గ్రామానికి తీవ్రమైన కష్టాలు వచ్చాయి… "
        ],
        "image": image_d1
        },
         {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#3
            "రైతు:అయ్యో! మా పంటలు ఎండిపోతున్నాయి… వర్షం లేదు… ఏం చేయాలి?"
        ],
        "image": image_d6
        },
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#4
            "గ్రామస్తులు:ఇది సాధారణం కాదు. ఏదో దైవ కోపం అనిపిస్తుంది."
        ],
        "image": image_d7
        },
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#5
            "గ్రామ పెద్ద:మన గ్రామాన్ని కాపాడే అమ్మను మనం మరచిపోయాం. పెద్దమ్మతల్లి మనల్ని పరీక్షిస్తోంది."
        ],
        "image": image_d11
    },
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#6
            "నారేటర్:అప్పుడు గ్రామ పెద్ద అందరిని ఒకచోటికి తీసుకెళ్లి ప్రార్థన చేయమని చెప్పాడు…"
        ],
        "image": image_d1
    },
    #9
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#7
            "గ్రామ పెద్ద:అందరూ కలిసి అమ్మను ప్రార్థిద్దాం. ఆమె కరుణిస్తే మన కష్టాలు పోతాయి."
        ],
        "image": image_d11
    },
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#8
            "గ్రామస్తులు (ఒక్కసారిగా):",
            "అమ్మా పెద్దమ్మతల్లి! మమ్మల్ని కాపాడు!"

        ],
        "image": image_d8
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#9
          "(దివ్య దర్శనం – పెద్దమ్మతల్లి ప్రత్యక్షం)",
          "పెద్దమ్మతల్లి:నా పిల్లలారా… మీరు నన్ను మరచిపోయారు. అందుకే ఈ కష్టాలు వచ్చాయి."
        ],
        "image": image_d4#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#10
          "(దివ్య దర్శనం – పెద్దమ్మతల్లి ప్రత్యక్షం)",
          "రైతు:అమ్మా! మాకు క్షమించు. ఇకముందు మిమ్మల్ని ఎప్పుడూ మర్చిపోము."
        ],
        "image": image_d6#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#11
          "(దివ్య దర్శనం – పెద్దమ్మతల్లి ప్రత్యక్షం)",
          "పెద్దమ్మతల్లి:ప్రతి సంవత్సరం నా జాతరను భక్తితో జరపండి. నేను మీ గ్రామాన్ని ఎల్లప్పుడూ కాపాడుతాను."
        ],
        "image": image_d4#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#12
          "(దివ్య దర్శనం – పెద్దమ్మతల్లి ప్రత్యక్షం)",
          "గ్రామ పెద్ద:అమ్మా! మీ ఆజ్ఞ ప్రకారం ప్రతి సంవత్సరం జాతరను ఘనంగా నిర్వహిస్తాము."
        ],
        "image": image_d11#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#13
          "(దివ్య దర్శనం – పెద్దమ్మతల్లి ప్రత్యక్షం)",
          "నారేటర్:అలా పెద్దమ్మతల్లి ఆశీర్వాదంతో గ్రామంలో మళ్లీ సంతోషం వచ్చింది.",
          "వర్షాలు కురిశాయి, పంటలు పుష్కలంగా పండాయి."
        ],
        "image": image_d10#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#14
          "జాతర ప్రారంభం",
          "గ్రామస్తులు:జై పెద్దమ్మతల్లి! జై జై పెద్దమ్మతల్లి!"
        ],
        "image": image_d5#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#15
          "జాతర ప్రారంభం",
          "నారేటర్:అప్పటి నుంచి ప్రతి సంవత్సరం శృంగవృక్షం గ్రామంలో పెద్దమ్మతల్లి జాతర ఎంతో",
          "ఘనంగా జరుగుతోంది. భక్తులు దూరదూరాల నుంచి వచ్చి అమ్మను దర్శించుకుంటారు."
        ],
        "image": image_d1#xhange
    },
    #4
    {
        "title": "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ",
        "text": [#16
          "ముగింపు సందేశం",
          "నారేటర్:మన గ్రామదేవతలను గౌరవిస్తే… వారు మనలను ఎల్లప్పుడూ కాపాడుతారు.",
          "భక్తి, విశ్వాసం ఉంటే… కష్టాలు కూడా సులభంగా తొలగిపోతాయి."
        ],
        "image": image_d9#xhange
    }
]
    # --- Video Generation Functions ---
width, height = 1920, 1080
fps = 24

def create_frame(title, subtitle, image_path):
    """Creates a single video frame with text and image."""
    img = Image.new('RGB', (width, height), color='black')
    draw = ImageDraw.Draw(img)
#font
    try:
        font_size_title = 70
        font_size_subtitle = 30
        title_font = ImageFont.truetype(telugu_font_path, font_size_title)
        subtitle_font = ImageFont.truetype(telugu_font_path, font_size_subtitle)
    except IOError:
        print("Warning: Font file not found. Using default font.")
        title_font = ImageFont.load_default()
        subtitle_font = ImageFont.load_default()

    if os.path.exists(image_path):
        bg_image = Image.open(image_path).resize((int(width * 0.7), int(height * 0.7)), Image.LANCZOS)
        img.paste(bg_image, ((width - bg_image.width) // 2, (height - bg_image.height) // 2))

    if title:
        draw.text((width // 2, 50), title, font=title_font, fill='gold', anchor="mt")

    y_text = height - 200
    # Wrap text and draw each line
    max_width = width - 200 # Adjust this value as needed for padding
    wrapped_lines = []
    for line in subtitle:
        wrapped_lines.extend(textwrap.wrap(line, width=int(max_width / (font_size_subtitle * 0.6)))) # Adjust width based on font size and cast to integer
#change
    for line in wrapped_lines:
        draw.text((width // 2, y_text), line, font=subtitle_font, fill='white', anchor="mt")
        y_text += 60 # Adjust line spacing as needed

    return cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)

def create_scene_video(scene_data, scene_index):
    """Creates a video clip for a single scene with synchronized audio."""
    voiceover_text = " ".join(scene_data["text"])
    audio_path = os.path.join(TEMP_FOLDER, f"scene_{scene_index}.mp3")

    if "Aparajita devia namaha" in voiceover_text:
        tts = gTTS(text=voiceover_text, lang='hi')
    else:
        tts = gTTS(text=voiceover_text, lang='te')

    tts.save(audio_path)

    audio_clip = AudioFileClip(audio_path)
    audio_duration = audio_clip.duration

    video_path = os.path.join(TEMP_FOLDER, f"scene_{scene_index}శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ.mp4")
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(video_path, fourcc, fps, (width, height))

    num_frames = int(audio_duration * fps)

    for _ in range(num_frames):
        frame = create_frame(scene_data["title"], scene_data["text"], scene_data["image"])
        out.write(frame)

    out.release()
    audio_clip.close()

    print(f"Created video for Scene {scene_index} with duration {audio_duration:.2f} seconds.")

    return video_path, audio_path

# --- Main Program Execution ---
if __name__ == "__main__":
    print("Starting video creation process...")

    video_clips = []

    for i, scene in enumerate(story_parts):
        try:
            video_path, audio_path = create_scene_video(scene, i)
            video_clip = VideoFileClip(video_path).set_audio(AudioFileClip(audio_path))
            video_clips.append(video_clip)

        except Exception as e:
            print(f"An error occurred while processing scene {i}: {e}")
            continue

    if video_clips:
        print("\nCombining all scenes into a final video...")
        final_video = concatenate_videoclips(video_clips)

        final_output_path = os.path.join(OUTPUT_FOLDER, "శృంగవృక్షం పెద్దమ్మతల్లి జాతర కథ.mp4")

        final_video.write_videofile(final_output_path, codec="libx264", audio_codec="aac")

        print(f"\n✅ Video created successfully at: {final_output_path}")

    else:
        print("\n❌ No video clips were created. Exiting.")

    import shutil
    shutil.rmtree(TEMP_FOLDER)
    print("Temporary files have been cleaned up.")

    try:
        from google.colab import files
        files.download(final_output_path)
    except ImportError:
        print("\nNote: The 'google.colab' library is not available. You can find your video file in the 'stotra_video_output' folder on the left-hand side file explorer.")
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':
# ...
